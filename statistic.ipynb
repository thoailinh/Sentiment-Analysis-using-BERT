# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/Khoa Luan/'

# %%
import pandas as pd
df_data3_train = pd.read_csv(path+'data3.csv')
df_data3_train = df_data2_train.dropna()
df_data3_test = pd.read_csv(path+'test3.csv')
df_data3_test = df_data2_test.dropna()

# %%
df_data3 = pd.concat([df_data3_test,df_data3_train])

# %%
df_data3
# Out:
#        Unnamed: 0                                             review  label
# 0               0          chất_lượng sản_phẩm tuyệt_vời positive ok      1
# 1               1  hang rat tot positive va dep positive rat dang...      1
# 2               2  tôi hy_vọng positive vào cuốn sách này của tờ ...      0
# 3               3  chất_lượng sản_phẩm rất kém negative cửa_hàng ...      0
# 4               4  hàng không giống trong hình cái cỡ nhưng khi n...      0
# ...           ...                                                ...    ...
# 42511       42516  nhiều món lâu negative mới quay lại đây quán v...      0
# 42512       42517  lụi bò lá_lốt bà lụi nướng chấm nước me ngọt n...      0
# 42513       42518  nem_lụi nước_chấm hơi nhạt thịt không có vị gì...      0
# 42514       42519  gành đá quán hải_sản tươi positive bạch tuột n...      1
# 42515       42520  review chiều vi_vu với con bạn thân nên ghé và...      0
#
# [57612 rows x 3 columns]

# %%
df_data3.label.value_counts()
# Out:
# 1    31280
# 0    26332
# Name: label, dtype: int64

# %%
df_data3_train.label.value_counts()
# Out:
# 1    22979
# 0    19537
# Name: label, dtype: int64

# %%
df_data3_test.label.value_counts()
# Out:
# 1    8301
# 0    6795
# Name: label, dtype: int64

# %%
data3_list = df_data3['review'].tolist()
count_words = [len(i.split()) for i in data3_list]
df_data3['count_words'] = count_words

# %%
df_data3.count_words.describe()
# Out:
# count    57612.000000
# mean        55.453187
# std         63.755933
# min          1.000000
# 25%         14.000000
# 50%         32.000000
# 75%         76.000000
# max       1435.000000
# Name: count_words, dtype: float64

# %%
df_foody_train = pd.read_csv(path+'NTC_SV/NTC_SV_train.csv')
df_foody_train = df_foody_train.dropna()
df_foody_test = pd.read_csv(path+'NTC_SV/NTC_SV_test.csv')
df_foody_test = df_foody_test.dropna()

# %%
df_foody = pd.concat([df_foody_train,df_foody_test])

# %%
df_foody
# Out:
#       Unnamed: 0                                             review  label
# 0              0  đồ_ăn ngon positive hợp_khẩu vị nhiều món nhân...      0
# 1              1  chè bơ thơm positive có vị ngậy ngậy nhưng lại...      0
# 2              2  chiều hôm nay mới đi ăn về nghe thiên_hạ đồn q...      0
# 3              3  mình đặt_hàng qua tin nhắn với cửa_hàng hứa sá...      0
# 4              4  ghé mấy lần rồi mà không review đi đâu cũng ch...      1
# ...          ...                                                ...    ...
# 9995        9995  hình_như là món mới của quán mới nhào vô uống ...      1
# 9996        9996  mình tới ngay ngày đầu_tiên khai_trương và nói...      0
# 9997        9997  hôm bữa đã đọc các comment quán này và thấy ho...      0
# 9998        9998  cả gia_đình du lich ra đà nẽng kem tuyết ngon ...      1
# 9999        9999  quán có món bông lan trứng muối ngon positive ...      0
#
# [50760 rows x 3 columns]

# %%
df_foody_train.label.value_counts()
# Out:
# 1    20493
# 0    20267
# Name: label, dtype: int64

# %%
df_foody_test.label.value_counts()
# Out:
# 1    5000
# 0    5000
# Name: label, dtype: int64

# %%
foody_list = df_foody['review'].tolist()
count_words2 = [len(i.split()) for i in foody_list]
df_foody['count_words'] = count_words2
df_foody['count_words'].describe()
# Out:
# count    50760.000000
# mean        86.572006
# std         77.401353
# min          1.000000
# 25%         37.000000
# 50%         65.000000
# 75%        111.000000
# max       1501.000000
# Name: count_words, dtype: float64
